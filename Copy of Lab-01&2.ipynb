# %%
list1=[1,2,3]
array1=np.array(list1)
array1
# Out:
# array([1, 2, 3])

# %%
import numpy as np
list2=[3,2,1]
array2=np.array(list2)
array2
# Out:
# array([3, 2, 1])

# %%
type(list1)
# Out:
# list

# %%
type(array1)
# Out:
# numpy.ndarray

# %%
print("array2 multiplied by array1: ",array1*array2)
print("array2 divide by array1: ",array2/array1)
print("array2 raised to the power of array1: ",array2**array1)
print(f"{array2} raised to the power of {array1}: ,{array2**array1}")
# Out:
# array2 multiplied by array1:  [3 4 3]
# array2 divide by array1:  [3.         1.         0.33333333]
# array2 raised to the power of array1:  [3 4 1]
# [3 2 1] raised to the power of [1 2 3]: ,[3 4 1]

# %%
# sine function
print("Sine: ",np.sin(array1))
print("Nature logarithm: ",np.log(array1))
print("Base-10 logarithm: ",np.log10(array1))
print("Base-2 logarithm: ",np.log2(array1))
#exponential
print("exponential: ",np.exp(array1))
# Out:
# Sine:  [0.84147098 0.90929743 0.14112001]
# Nature logarithm:  [0.         0.69314718 1.09861229]
# Base-10 logarithm:  [0.         0.30103    0.47712125]
# Base-2 logarithm:  [0.        1.        1.5849625]
# exponential:  [ 2.71828183  7.3890561  20.08553692]

# %%
print("Adding two numpy arrays{array1} and {array2} together:",array1+array2)
# Out:
# Adding two numpy arrays{array1} and {array2} together: [4 4 4]

# %%
print(f"Adding two numpy arrays{array1} and {array2} together: {array1+array2}")
# Out:
# Adding two numpy arrays[1 2 3] and [3 2 1] together: [4 4 4]

# %%
people=['ann','sonu','monu','gunnu','aadi','chuuza','rani','prince']
age=[21,19,18,14,20,21,16,22]
height=[160,145,170,165,173,168,175,159]
weight=[67,45,70,43,25,36,50,54]
import matplotlib.pyplot as plt

plt.scatter(weight, height)
plt.title("relationship between weight and height of patients")
plt.ylabel("height in meters")
plt.xlabel("weight of patient in kgs")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-284ab9697d0c> in <cell line: 9>()
#       7 plt.scatter(weight, height)
#       8 plt.title("relationship between weight and height of patients")
# ----> 9 plt.ylable("height in meters")
#      10 plt.xlabel("weight of patient in kgs")
#      11 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'ylable'

# %%
plt.figure(figsize=(12,4))
plt.title("People's weight in kgs",fontsize=16,
          fontstyle='italic')

#Main plot function 'bar'
plt.bar(x=people,height=weight,width=0.6,
        color='orange',edgecolor='k',alpha=0.6)

plt.xlabel("People",fontsize=15)
plt.ylabel("Weight (in kgs)",fontsize=15)
plt.show()

# %%
import numpy as np
plt.figure(figsize=(7,5))
plt.hist(weight,color='red',edgecolor='k',alpha=0.75,bins=5)
plt.title("Histogram of patient weight",fontsize=18)
plt.xlabel("Weight in kgs",fontsize=15)
plt.show()

# %%
import numpy as np
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df1=pd.read_csv("/content/drive/MyDrive/Spd.csv")
df2=pd.read_csv("/content/drive/MyDrive/pp.txt")
df3=pd.read_excel("/content/drive/MyDrive/Historicalinvesttemp.xlsx")

# %%
df1
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
df2
# Out:
#   First line: This is a test file
# 0             This is second line
# 1                      third line
# 2          and subsiquent lines..
# 3                      and more..

# %%
df3
# Out:
#    Unnamed: 0                        Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0         NaN                               NaN        NaN        NaN
# 1         NaN                               NaN        NaN        NaN
# 2         NaN                               NaN        NaN        NaN
# 3         NaN                               NaN        NaN        NaN
# 4         NaN  Annual Returns on Investments in        NaN        NaN
# ..        ...                               ...        ...        ...
# 85       2007                            0.0549     0.0988     0.0466
# 86       2008                             -0.37     0.2587      0.016
# 87       2009                            0.2646     -0.149      0.001
# 88        NaN                            stocks     tbills      bonds
# 89   averages                               NaN        NaN        NaN
#
# [90 rows x 4 columns]

# %%
import numpy as np
from queue import Queue
graph={
    0:[1,2,3],
    1:[0,2],
    2:[0,1,3,5],
    3:[0,2,4],
    4:[3,5,7],
    5:[4,6,7],
    6:[5,7],
    7:[4,5,6],
    8:[]
}
print("The adjecency list represent")

# %%
graph1={
    'A':['C','D','G'],
    'B':['F'],
    'C':['A','D','F'],
    'D':['A','C','E','G','H'],
    'E':['D','F','H'],
    'F':['C','E'],
    'G':['A','D','H'],
    'H':['D','E','G'],
}
print("The adjaceny List representing the graph is :")
print(graph1)
# Out:
# The adjaceny List representing the graph is :
# {'A': ['C', 'D', 'G'], 'B': ['F'], 'C': ['A', 'D', 'F'], 'D': ['A', 'C', 'E', 'G', 'H'], 'E': ['D', 'F', 'H'], 'F': ['C', 'E'], 'G': ['A', 'D', 'H'], 'H': ['D', 'E', 'G']}

# %%
def dfs(graph,node,visited):
  if node not in visited:
    visited.append(node)
    for k in graph[node]:
      dfs(graph,k,visited)
    return visited

visited = dfs(graph1,'B',[])
print(visited)
# Out:
# ['B', 'F', 'C', 'A', 'D', 'E', 'H', 'G']

# %%
  import numpy as np
  from queue import Queue
  import heapq

# %%
def bestFirstSearch(intial_sate, goal_state, evaluation_function):
  priority_queue =[]
  heapq.heappush(priority_queue, evaluation_function(intial_state), intial_state)

  while priority_queue:
    current_state = heapq.heappop(priority_queue [1])

    if current_state ** goal_state:
      return current_state

    next_states = generateNextState(current_state)
    for next_state in next_states:
      priority_value = evaluation_function(next_state)
      heapq.heappush(priority_queue, priority_value, next_state)

  return "No solution found"

# %%
def evaluationFunction (state):
  return abs(state [0] - goal_state[0]) + abs(state[1]- goal_state[1])

def generateNextState(state):
  x,y = state
  next_state = [ (x+1,y), (x-1,y),(x,y+1),(x,y-1)]
  return[ s for s in next_state if 0<= s[0] <= 4 and 0<= s[1] <= 4]
intial_state = [0,0]
goal_state = [4,4]

solution = bestFirstSearch(intial_state, goal_state, evaluation_function)
print("Solution:",solution)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-331c8969ef0e> in <cell line: 11>()
#       9   goal_state = [4,4]
#      10
# ---> 11 solution = bestFirstSearch(intial_state, goal_state, evaluationFunction)
#      12 print("Solution:",solution)
#
# <ipython-input-33-555a15ff3a87> in bestFirstSearch(intial_sate, goal_state, evaluation_function)
#       1 def bestFirstSearch(intial_sate, goal_state, evaluation_function):
#       2   priority_queue =[]
# ----> 3   heapq.heappush(priority_queue, evaluation_function(intial_state), intial_state)
#       4
#       5   while priority_queue:
#
# TypeError: heappush expected 2 arguments, got 3

# %%
from copy import deepcopy
import numpy as np
import time

def bestsolution(state):
  bestsol = np.array([], int).reshape(-1, 9)
  count = len(state) - 1
  while count != -1:
    bestsol = np.insert(bestsol, 0, state[count]['puzzle'], 0)
    count = state['count']['parent']
  return bestsol.reshape(-1,3,3)

# %%
def all(checkarray):
  set = []
  for it in set:
    for checkarray in it:
      return 1
    else:
      return 0

# %%
def misplaced_tiles(puzzle, goal):
  mscost = np.sum(puzzle != goal) - 1
  return mscost if mscost > 0 else 0

# %%
def coordinates(puzzle):
  pos = np.array(range(9))
  for p,q in enumerate(puzzle):
    pos[q] = p
  return pos

# %%
def evaluate_misplaced(puzzle, goal):
  steps = np.array([
      ('up',[0,1,2], -3),
      ('down',[6,7,8], 3),
      ('left',[0,3,6], -1),
      ('right',[2,5,8], 1)
  ],dtype=[('move', str, 1),('position', list),('head', int)])
  dtstate = [('puzzle', list),('parent', int), ('gn', int), ('hn', int)]
  costg = coordinates(goal)
  parent = -1
  gn = 0
  hn = misplaced_tiles(coordinates(puzzle), costg)
  state = np .array([(puzzle, parent, gn, hn)], dtstate)

# %%
def evaluate_misplaced(puzzle, goal):
  steps = np.array([
      ('up',[0,1,2], -3),
      ('down',[6,7,8], 3),
      ('left',[0,3,6], -1),
      ('right',[2,5,8], 1)
  ],dtype=[('move', str, 1),('position', list),('head', int)])
  dtstate = [('puzzle', list),('parent', int), ('gn', int), ('hn', int)]
  costg = coordinates(goal)
  parent = -1
  gn = 0
  hn = misplaced_tiles(coordinates(puzzle), costg)
  state = np .array([(puzzle, parent, gn, hn)], dtstate)
  dtpriority = [('position', int), ('fn', int)]
  priority = np.array([(0, hn)], dtpriority)
  while True:
    priority = np.sort(priority, kind='mergesort', order=['fn', 'position'])
    position, fn = priority[0]
    priority = np.delete(priority, 0,0)
    puzzle, parent, gn, hn = state[position]

# %%
def evaluate_misplaced(puzzle, goal):
  steps = np.array([
      ('up',[0,1,2], -3),
      ('down',[6,7,8], 3),
      ('left',[0,3,6], -1),
      ('right',[2,5,8], 1)
  ],dtype=[('move', str, 1),('position', list),('head', int)])
  dtstate = [('puzzle', list),('parent', int), ('gn', int), ('hn', int)]
  costg = coordinates(goal)
  parent = -1
  gn = 0
  hn = misplaced_tiles(coordinates(puzzle), costg)
  state = np .array([(puzzle, parent, gn, hn)], dtstate)
  dtpriority = [('position', int), ('fn', int)]
  priority = np.array([(0, hn)], dtpriority)
  while True:
    priority = np.sort(priority, kind='mergesort', order=['fn', 'position'])
    position, fn = priority[0]
    priority = np.delete(priority, 0,0)
    puzzle, parent, gn, hn = state[position]
    puzzle = np.array(puzzle)
    blank = int(np.where(puzzle == 0)[0])
    gn = gn + 1
    c = 1
    start_time = time.time()
    for s in steps:
      c = c + 1
      if blank not in s['position']:
        openstates = deepcopy(state)
        openstates[blank], openstates[blank + s['head']] = openstates[blank + s['head']]

        if not (np.all(list(state['puzzle']) == openstates,1)).any():
          end_time = time.time()
          if (end_time - start_time) > 2:
            print("The 8-puzzle is unsolvable\n")
            break
          hn = misplaced_tiles(coordinates(openstates), costg)
          q = np.array([(openstates, position, gn, hn)], dtstate)
          state = np.append(state, q, 0)
          fn = gn + hn
          q = np.array([(len(state) - 1, fn)], dtpriority)
          priority = np.append(priority, q, 0)
          if np.array_equal(openstates, goal):
            print('The 8-puzzle is solvable\n')
            return state,len(priority)
  return state,len(priority)

# %%
puzzle = []
puzzle.append(2)
puzzle.append(8)
puzzle.append(3)
puzzle.append(1)
puzzle.append(6)
puzzle.append(4)
puzzle.append(7)
puzzle.append(0)
puzzle.append(5)

goal = []
goal.append(1)
goal.append(2)
goal.append(3)
goal.append(8)
goal.append(0)
goal.append(4)
goal.append(7)
goal.append(6)
goal.append(5)

state, visited = evaluate_misplaced(puzzle, goal)
bestpath = bestsolution(state)
print(str)
print('Cost of best solution:', visited
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-e7edd656f31e> in <cell line: 23>()
#      21 goal.append(5)
#      22
# ---> 23 state, visited = evaluate_misplaced(puzzle, goal)
#
# <ipython-input-9-759dad94658d> in evaluate_misplaced(puzzle, goal)
#      10   parent = -1
#      11   gn = 0
# ---> 12   hn = misplaced_tiles(coordinates(puzzle), costg)
#      13   state = np .array([(puzzle, parent, gn, hn)], dtstate)
#      14   dtpriority = [('position', int), ('fn', int)]
#
# NameError: name 'misplaced_tiles' is not defined
